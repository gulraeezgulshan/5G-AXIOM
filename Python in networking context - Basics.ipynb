# %% [markdown]
# # Learning Python in Networking Context

# %%
hostname = 'ROUTER_1'

# Notice that you did not need to declare the variable first or define that hostname was going to be of type string.
# This is a departure from some programming languages such as C and Java, and a reason why Python is called a dynamic language.

# %%
print(hostname)
# Out:
# ROUTER_1

# %%
#Escape sequences
banner = "\n\n     WELCOME TO ROUTER_1     \n\n"

# %%
print(banner)
# Out:
#      WELCOME TO ROUTER_1

# %%
banner
# Out:
# '\n\n     WELCOME TO ROUTER_1     \n\n'

# %% [markdown]
# ### Can you see the difference?

# %%
hostname = 'ROUTER_1"
# Out:
#   File "<ipython-input-7-807a3ecec281>", line 1
#     hostname = 'ROUTER_1"
#                          ^
# SyntaxError: EOL while scanning string literal

# %%
hostname = 'ROUTER_1'
hostname = "ROUTER_1"

# %% [markdown]
# # Understanding Python Data Types

# %%
"router1".upper()
# Out:
# 'ROUTER1'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Learning to Use Strings

# %%
final = 'The IP address of router1 is: '

# %%
final
# Out:
# 'The IP address of router1 is: '

# %%
ipaddr = '1.1.1.1'
ipaddr
# Out:
# '1.1.1.1'

# %%
type(final)
# Out:
# str

# %%
type(ipaddr)
# Out:
# str

# %%
type(1)
# Out:
# int

# %%
#Concatenation

final + ipaddr
# Out:
# 'The IP address of router1 is: 1.1.1.1'

# %%
print('The IP address of router1 is: ' + ipaddr)
# Out:
# The IP address of router1 is: 1.1.1.1

# %%
2+2
# Out:
# 4

# %%
'2'+'2'
# Out:
# '22'

# %%
print('The IP address of router1 is:',ipaddr)
# Out:
# The IP address of router1 is: 1.1.1.1

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
dir(hostname)

# %%
dir(int)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'numerator',
#  'real',
#  'to_bytes']

# %%
dir(str)

# %%
help(str.upper)
# Out:
# Help on method_descriptor:
#
# upper(self, /)
#     Return a copy of the string converted to uppercase.

# %%
help(hostname.upper)

# %%
interface = 'Ethernet1/1'

# %%
interface.lower()
# Out:
# 'ethernet1/1'

# %%
# upper() is method which is returning an output

interface.upper()
# Out:
# 'ETHERNET1/1'

# %%
intf_lower = interface.lower()

# %%
print(intf_lower)
# Out:
# ethernet1/1

# %%
# Original value is un-modified
print(interface)
# Out:
# Ethernet1/1

# %%
ipaddr = '10.100.20.5'

# %%
ipaddr.startswith('10')
# Out:
# True

# %%
ipaddr.startswith('100')
# Out:
# False

# %%
ipaddr.endswith('.5')
# Out:
# True

# %%
ipaddr.endswith('.500')
# Out:
# False

# %%
# Python implies case-senstivity

interface = 'Eth1/1'
interface.startswith('et')
# Out:
# False

# %%
interface = 'Eth1/1'
#interface.startswith('Et')
'Eth1/1'.startswith('Et')
# Out:
# True

# %%
# Method chaining / Nesting

interface = 'Eth1/1' # eth1/1
interface.lower().startswith('et')
# Out:
# True

# %%
#Whitespaces 

ipaddr = '     10.1.50.1       '
ipaddr.startswith('10')
#ipaddr.startswith(' ')
# Out:
# False

# %%
print(ipaddr)
print(ipaddr.strip())
# Out:
#      10.1.50.1
# 10.1.50.1

# %%
# Return a copy of the string with leading and trailing whitespace removed.
help(str.strip)
# Out:
# Help on method_descriptor:
#
# strip(self, chars=None, /)
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
ipaddr.strip().startswith('10')
# Out:
# True

# %%
# lstrip() or rstrip()
ipaddr.lstrip()
# Out:
# '10.1.50.1       '

# %%
ipaddr.rstrip()
# Out:
# '     10.1.50.1'

# %%
# (), {}, '', "",  Leading => Start, trailing => End

ten = '10'
#ten = 10
ten
# Out:
# '10'

# %%
type(ten)
# Out:
# str

# %%
ten.isdigit()
# Out:
# True

# %%
bogus = '10a'

# %%
bogus.isdigit()
# Out:
# False

# %%
octet = '111111000'

# %%
octet.count('1')
# Out:
# 5

# %%
octet.count('111')
# Out:
# 1

# %%
octet.count('11')
# Out:
# 3

# %%
octet.count('10')
# Out:
# 1

# %%
mask = '255.255.255.0'
mask.count('255')
# Out:
# 3

# %%
test_string = "Don't you wish you started programming a little earlier?"
test_string.count('you')
# Out:
# 2

# %%
# assume the command that needs to be created is the following: ping 8.8.8.8 vrf management

ipaddr = '8.8.8.8'
vrf = 'management'

# %%
ping = 'ping' + ipaddr + 'vrf' + vrf
print(ping)
# Out:
# ping8.8.8.8vrfmanagement

# %%
ping = 'ping' + ' ' + ipaddr + ' ' + 'vrf' + ' ' + vrf
print(ping)
# Out:
# ping 8.8.8.8 vrf management

# %% [markdown]
# This works quite well and is not too complicated, but as the strings or commands get longer, it can get quite messy dealing with all of the quotes and spaces. Using the format() method can simplify this.

# %%
# 0,1,2,3

ping = 'ping {} vrf {}'.format(ipaddr, vrf)
print(ping)
# Out:
# ping 8.8.8.8 vrf management

# %%
ping = 'ping {} vrf {}'.format(vrf, ipaddr)
print(ping)
# Out:
# ping management vrf 8.8.8.8

# %%
ping = 'ping {0} vrf {1}'.format(ipaddr, vrf)
print(ping)
# Out:
# ping 8.8.8.8 vrf management

# %%
ping = 'ping {1} vrf {0}'.format(ipaddr, vrf)
print(ping)
# Out:
# ping management vrf 8.8.8.8

# %%
ping = 'ping {} vrf {}'
command = ping.format(ipaddr, vrf)
print(command)
# Out:
# ping 8.8.8.8 vrf management

# %%
hostnames = ['r1', 'r2', 'r3', 'r4', 'r5']
commands = ['config t', 'interface Ethernet1/1', 'shutdown']

# %%
hostnames
# Out:
# ['r1', 'r2', 'r3', 'r4', 'r5']

# %%
commands
# Out:
# ['config t', 'interface Ethernet1/1', 'shutdown']

# %%
# \n special character / Escape Sequence
commands = ['config t', 'interface Ethernet1/1', 'shutdown']
joint_str = '\n\n'.join(commands)
print(joint_str)
# Out:
# config t
#
# interface Ethernet1/1
#
# shutdown

# %%
' ; '.join(commands)
# Out:
# 'config t ; interface Ethernet1/1 ; shutdown'

# %%
# delimeter a | b | c
# a & b & c
# a & b $ c

commands = 'config t;interface Ethernet1/1;shutdown'
cmds_list = commands.split(';')
print(cmds_list)
# Out:
# ['config t', 'interface Ethernet1/1', 'shutdown']

# %%
commands = ['config t', 'interface Ethernet1/1', 'shutdown']
sample = ';'.join(commands).split(';')
print(sample)
# Out:
# ['config t', 'interface Ethernet1/1', 'shutdown']

# %%
commands == sample
# Out:
# True

# %%
# join => converting LIST to STR
# split => coverting STR to LIST based on delimeter

ipaddr = '10.1.20.30'
ipaddr.split('.')
# Out:
# ['10', '1', '20', '30']

# %% [markdown]
# ## Learning to Use Numbers

# %%
cpu = 41.3

# %%
a = 1
type(a)
# Out:
# int

# %%
a = 1.0
type(a)
# Out:
# float

# %%
a = 1.
type(a)
# Out:
# float

# %%
type(cpu)
# Out:
# float

# %%
5 + 3
# Out:
# 8

# %%
5 + 'a'
# Out:
# --------------------------------------------------------------------------
# TypeError                                Traceback (most recent call last)
# <ipython-input-109-f2c23ab0a5e1> in <module>
# ----> 1 5 + 'a'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(5) + 'a'
# Out:
# '5a'

# %%
'2' + 2
# Out:
# --------------------------------------------------------------------------
# TypeError                                Traceback (most recent call last)
# <ipython-input-111-7e1e50100c0b> in <module>
# ----> 1 '2'+2
#
# TypeError: can only concatenate str (not "int") to str

# %%
int('2') + 2
# Out:
# 4

# %%
a = 1
b = 2
a + b
# Out:
# 3

# %%
a = 1
#a = a + 1 # increment by one
a += 1
a
# Out:
# 2

# %%
counter = 5
counter += 5 # counter = counter+5
counter
# Out:
# 10

# %%
counter = 10
counter -= 5 # counter = counter - 5
counter
# Out:
# 5

# %%
100 - 90
# Out:
# 10

# %%
count = 50
count - 20
# Out:
# 30

# %%
100 * 50
# Out:
# 5000

# %%
print(2 * 25)
# Out:
# 50

# %%
2*2
# Out:
# 4

# %%
'2'*10
# Out:
# '2222222222'

# %%
'='*40
# Out:
# '========================================'

# %%
print('*' * 50)
# Out:
# **************************************************

# %%
print('=' * 50)
# Out:
# ==================================================

# %%
100 / 50
# Out:
# 2.0

# %%
10/ 2
# Out:
# 5.0

# %%
12 / 10
# Out:
# 1.2

# %%
# Modulo Operator / It yields remainder
#12 % 10

12 % 2

2222 % 1000
# Out:
# 222

# %% [markdown]
# ## Learning to Use Booleans

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# True | False

# %%
exists = True
type(exists)
# Out:
# bool

# %%
exists = true
# Out:
# --------------------------------------------------------------------------
# NameError                                Traceback (most recent call last)
# <ipython-input-140-072edba20e59> in <module>
# ----> 1 exists = true
#
# NameError: name 'true' is not defined

# %%
True and True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
value1 = True
value2 = True

# %%
value1 and value2
# Out:
# False

# %%
value1 or value2
# Out:
# True

# %%
value3 = True
value4 = True

# %%
value1 and value2 and value3 and value4
# Out:
# True

# %%
value1 and value3 and value4

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %%
(2 == 2) and (4 == 4) and (10 > 20)
# Out:
# False

# %%
is_layer3 = True
not is_layer3
# Out:
# False

# %%
True == True
# Out:
# True

# %%
#not equal to !=
True != False
# Out:
# True

# %%
False == True
# Out:
# False

# %%
'network' == 'network'
# Out:
# True

# %%
'network' == 'no_network'
# Out:
# False

# %% [markdown]
# ## Learning to Use Python Lists

# %%
# [], same-type elements, mixed-type elements)

hostnames = ['r1', 'r2', 'r3', 'r4', 'r5']
commands = ['config t', 'interface Ethernet1/1', 'shutdown']
new_list = ['router1', False, 5]

# %%
print(hostnames)
print(commands)
print(new_list)
# Out:
# ['r1', 'r2', 'r3', 'r4', 'r5']
# ['config t', 'interface Ethernet1/1', 'shutdown']
# ['router1', False, 5]

# %%
print(type(hostnames))
print(type(commands))
print(type(new_list))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
# Lists are ordered.
# Indexing / Serial Number / starting from 0 / position

# Left to Right [0,1,2,3,......]
# Right to Left [.....-4, -3, -2, -1]

interfaces = ['Eth1/1', 'Eth1/2', 'Eth1/3', 'Eth1/4'] # static
#lenght = 4

# %%
print(interfaces[0])
print(interfaces[1])
print(interfaces[2])
print(interfaces[3])

print('-'*20)

print(interfaces[-4])
print(interfaces[-3])
print(interfaces[-2])
print(interfaces[-1])
# Out:
# Eth1/1
# Eth1/2
# Eth1/3
# Eth1/4
# --------------------
# Eth1/1
# Eth1/2
# Eth1/3
# Eth1/4

# %%
len(interfaces)
# Out:
# 4

# %%
interfaces[0] # Positive Indexing
interfaces[-1] # Negative Indexing
# Out:
# 'Eth1/4'

# %%
dir(interfaces)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
#Empty List
vendors = []

# %%
print(vendors)
# Out:
# []

# %%
# dynamically populate
# Jargons

vendors.append('arista')
print(vendors)
# Out:
# ['arista']

# %%
vendors.append('cisco')
print(vendors)
# Out:
# ['arista', 'cisco']

# %%
vendors.append('juniper')
print(vendors)
# Out:
# ['arista', 'cisco', 'juniper', 'juniper']

# %% [markdown]
# * You can see that using append() adds the element to the last position in the list.
# * In contrast to many of the methods reviewed for strings, this method is not returning anything, but modifying the original variable, or object.

# %%
commands = ['interface Eth1/1', 'ip address 1.1.1.1/32']

# %%
commands.insert(0, 'config t')

# %%
print(commands)
# Out:
# ['config t', 'interface Eth1/1', 'ip address 1.1.1.1/32']

# %%
commands.insert(2, 'no switchport')

# %%
print(commands)
# Out:
# ['config t', 'interface Eth1/1', 'no switchport', 'ip address 1.1.1.1/32']

# %%
vendors = ['cisco', 'cisco', 'juniper', 'arista', 'cisco', 'hp', 'cumulus', 'arista', 'cisco']

# %%
vendors
# Out:
# ['cisco',
#  'cisco',
#  'juniper',
#  'arista',
#  'cisco',
#  'hp',
#  'cumulus',
#  'arista',
#  'cisco']

# %%
vendors.count('cisco')
# Out:
# 4

# %%
vendors.count('arista')
# Out:
# 2

# %%
hostnames = ['r1', 'r2', 'r3', 'r4', 'r5']

# %%
hostnames.pop().pop()
# Out:
# --------------------------------------------------------------------------
# AttributeError                           Traceback (most recent call last)
# <ipython-input-198-41ab4bf9746a> in <module>
# ----> 1 hostnames.pop().pop()
#
# AttributeError: 'str' object has no attribute 'pop'

# %%
help(list.pop)
# Out:
# Help on method_descriptor:
#
# pop(self, index=-1, /)
#     Remove and return item at index (default last).
#
#     Raises IndexError if list is empty or index is out of range.

# %%
hostnames.pop()
# Out:
# 'r4'

# %%
# the element being popped is returned and the original list is modified as well.
hostnames
# Out:
# ['r1', 'r2', 'r3', 'r4']

# %%
# pop() empty parameters means the last index by default (-1)
hostnames.pop()
# Out:
# 'r4'

# %%
hostnames
# Out:
# ['r1', 'r2', 'r3', 'r4', 'r5']

# %%
#hostnames.pop('r2')
hostnames.pop(1)
# Out:
# 'r2'

# %%
hostnames
# Out:
# ['r1', 'r3', 'r4', 'r5']

# %%
hostnames.index('r4')
# Out:
# 2

# %%
hostnames.pop(hostnames.index('r5'))
# Out:
# 'r5'

# %%
hostnames
# Out:
# ['r1', 'r3']

# %%
hostnames.pop(1)

# %%
print(hostnames)

# %%
hostnames.pop(hostnames.index('r3'))

# %%
print(hostnames)

# %%
hostnames.pop('r1')

# %%
available_ips = ['10.1.1.1', '10.1.1.9', '10.1.1.8', '10.1.1.7', '10.1.1.4']
available_ips
# Out:
# ['10.1.1.1', '10.1.1.9', '10.1.1.8', '10.1.1.7', '10.1.1.4']

# %%
#sort() is used to update the original object.
available_ips.sort()
available_ips
# Out:
# ['10.1.1.1', '10.1.1.4', '10.1.1.7', '10.1.1.8', '10.1.1.9']

# %%
available_ips
# Out:
# ['10.1.1.1', '10.1.1.4', '10.1.1.7', '10.1.1.8', '10.1.1.9']

# %% [markdown]
# ## Learning to Use Python Dictionaries

# %%
device = ['router1', 'juniper', '12.2']

device = {'hostname': 'router1', 
          'vendor': 'juniper', 
          'os': '12.1'}

# %%
print(device['hostname'])
print(device['os'])
print(device['vendor'])
# Out:
# router1
# 12.1
# juniper

# %%
print(device)
# Out:
# {'hostname': 'router1', 'vendor': 'juniper', 'os': '12.1'}

# %%
device = {}
device
# Out:
# {}

# %%
# Populating dictionary using keys

device['hostname'] = 'router1'
device['vendor'] = 'juniper'
device['os'] = '12.1'

print(device)
# Out:
# {'hostname': 'router1', 'vendor': 'juniper', 'os': '12.1'}

# %%
device = dict(hostname='router1', vendor='juniper', os='12.1')
print(device)
# Out:
# {'hostname': 'router1', 'vendor': 'juniper', 'os': '12.1'}

# %%
dir(dict)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
device
# Out:
# {'hostname': 'router1', 'vendor': 'juniper', 'os': '12.1'}

# %%
print(device['model'])
# Out:
# --------------------------------------------------------------------------
# KeyError                                 Traceback (most recent call last)
# <ipython-input-227-d8dbeb4382d3> in <module>
# ----> 1 print(device['model'])
#
# KeyError: 'model'

# %%
print(device.get('model'))
# Out:
# None

# %%
device.get('hostname')
# Out:
# 'router1'

# %%
device.get('model', False)
# Out:
# False

# %%
device.get('model', 'DOES NOT EXIST')
# Out:
# 'DOES NOT EXIST'

# %%
device.get('hostname', 'DOES NOT EXIST')
# Out:
# 'router1'

# %%
device
# Out:
# {'hostname': 'router1', 'vendor': 'juniper', 'os': '12.1'}

# %%
device.keys()
# Out:
# dict_keys(['hostname', 'vendor', 'os'])

# %%
device.values()
# Out:
# dict_values(['router1', 'juniper', '12.1'])

# %%
device
# Out:
# {'hostname': 'router1', 'vendor': 'juniper', 'os': '12.1'}

# %%
device.pop('vendor')
# Out:
# 'juniper'

# %%
device
# Out:
# {'hostname': 'router1', 'os': '12.1'}

# %%
device = {'hostname': 'router1', 'vendor': 'juniper', 'os': '12.1'}
oper = dict(cpu='5%', memory='10%')

# %%
print(device)
print(oper)
# Out:
# {'hostname': 'router1', 'vendor': 'juniper', 'os': '12.1'}
# {'cpu': '5%', 'memory': '10%'}

# %%
device.update(oper)

# %%
print(device)
# Out:
# {'hostname': 'router1', 'vendor': 'juniper', 'os': '12.1', 'cpu': '5%', 'memory': '10%'}

# %%
device.update({'ip':'192.168.1.1'})

# %%
device
# Out:
# {'hostname': 'router1',
#  'vendor': 'juniper',
#  'os': '12.1',
#  'cpu': '5%',
#  'memory': '10%',
#  'ip': '192.168.1.1'}

# %%
#iterators

device.items()
# Out:
# dict_items([('hostname', 'router1'), ('vendor', 'juniper'), ('os', '12.1'), ('cpu', '5%'), ('memory', '10%'), ('ip', '192.168.1.1')])

# %%
for key,value in device.items():
    print(key + ' : ' + value)
# Out:
# hostname : router1
# vendor : juniper
# os : 12.1
# cpu : 5%
# memory : 10%
# ip : 192.168.1.1

# %%
for k in device.keys():
    print(k)
# Out:
# hostname
# vendor
# os
# cpu
# memory
# ip

# %%
for v in device.values():
    print(v)
# Out:
# router1
# juniper
# 12.1
# 5%
# 10%
# 192.168.1.1

# %% [markdown]
# ## Learning About Python Sets and Tuples

# %%
vendors = set(['arista', 'cisco', 'arista', 'cisco', 'juniper', 'cisco'])
vendors

# %%
len(vendors)

# %%
vendors[0]

# %% [markdown]
# In order to access elements in a set, you must iterate through them, using a for loop as an example.

# %%
description = tuple(['ROUTER1', 'PORTLAND'])
description

# %%
print(description[0])

# %%
description[1] = 'trying to modify one'

# %%
dir(tuple)

# %% [markdown]
# * Lists are mutable, they can be modified, individual elements they can be accessed directly, and can have duplicate values.
# * Sets are mutable, they can be modified, individual elements cannot be accessed directly, and they cannot have duplicate values.
# * Tuples are immutable, they cannot be updated or modified once created, individual elements can be accessed directly, and they can have duplicate values.

# %% [markdown]
# # Adding Conditional Logic to Your Code

# %%
hostname = 'NYC'
if hostname == 'NYC':
    print('The hostname is NYC')

# %%
if hostname == 'NYC':
    print('This hostname is NYC')
    print(len(hostname))
    print('The End.')

# %%
hostname = 'NJ'

if hostname == 'NYC':
    print('This hostname is NYC')
elif hostname == 'NJ':
    print('This hostname is NJ')

# %%
hostname = 'DEN_CO'

if hostname == 'NYC':
    print('This hostname is NYC')
elif hostname == 'NJ':
    print('This hostname is NJ')
else:
    print('UNKNOWN HOSTNAME')

# %%
if hostname == 'NYC':
    print('This hostname is NYC')
 elif hostname == 'NJ':

# %%
if hostname == 'NYC'
    print('Test')

# %% [markdown]
# # Understanding Containment

# %%
vendors = ['arista', 'juniper', 'big_switch', 'cisco']

# %%
'arista' in vendors

# %%
if 'arista' in vendors:
    print('Arista is deployed.')

# %%
version = "CSR1000V Software (X86_64_LINUX_IOSD-UNIVERSALK9-M),Version 16.3.1, RELEASE"

# %%
"16.3.1" in version

# %%
if "16.3.1" in version:
    print("Version is 16.3.1!!")

# %% [markdown]
# # Using Loops in Python

# %% [markdown]
# ## Understanding the while Loop

# %%
counter = 1

while counter < 5:
    print(counter)
    counter += 1

# %% [markdown]
# ## Understanding the for Loop

# %%
vendors

# %%
for vendor in vendors:
    print('VENDOR '+vendor)

# %%
vendors = ['arista', 'juniper', 'big_switch', 'cisco', 'oreilly']
approved_vendors = ['arista', 'juniper', 'big_switch', 'cisco']

# %%
for vendor in vendors:
    if vendor not in approved_vendors:
        print('NETWORK VENDOR NOT APPROVED: ' + vendor)

# %%
COMMANDS = { 'description': 'description {}', 'speed': 'speed {}', 'duplex': 'duplex {}' }
CONFIG_PARAMS = {'description': 'auto description by Python', 'speed': '10000', 'duplex': 'auto'}

# %%
commands_list = []

for feature, value in CONFIG_PARAMS.items():
    command = COMMANDS.get(feature).format(value)
    commands_list.append(command)

# %%
commands_list.insert(0, 'interface Eth1/1')

# %%
print(commands_list)

# %%
vendors = ['arista', 'juniper', 'big_switch', 'cisco']

for index, each in enumerate(vendors):
    print(index + ' ' + each)

# %%
vendors = ['arista', 'juniper', 'big_switch', 'cisco']

for index, each in enumerate(vendors):
    print(str(index) + ' ' + each)

# %%
for index, each in enumerate(vendors):
    if each == 'arista':
        print('arista index is: ' + str(index))

# %% [markdown]
# # Using Python Functions

# %%
def print_vendor(net_vendor):
    print(net_vendor)

# %%
vendors = ['arista', 'juniper', 'big_switch', 'cisco']

for vendor in vendors:
    print_vendor(vendor)

# %%
def get_commands(vlan, name):
    commands = []
    commands.append('vlan ' + vlan)
    commands.append('name ' + name)
    
    return commands

def push_commands(device, commands):
    print('Connecting to device: ' + device)
    for cmd in commands:
        print('Sending command: ' + cmd)

# %%
devices = ['switch1', 'switch2', 'switch3']
vlans = [{'id': '10', 'name': 'USERS'}, {'id': '20', 'name': 'VOICE'}, {'id': '30', 'name': 'WLAN'}]

# %%
for vlan in vlans:
    id = vlan.get('id')
    name = vlan.get('name')
    print('\n')
    print('CONFIGURING VLAN:' + id)
    commands = get_commands(id, name)
    for device in devices:
        push_commands(device, commands)
        print('\n')

# %% [markdown]
# # Working with Files

# %% [markdown]
# ## Reading from a File

# %%
vlans_file = open('vlans.cfg', 'r')
vlans_file.read()

# %%
vlans_file.close()

# %%
vlans_file = open('vlans.cfg', 'r')
vlans_file.readlines()

# %%
vlans_file.close()

# %%
vlans_file = open('vlans.cfg', 'r')
vlans_text = vlans_file.read()
vlans_list = vlans_text.splitlines()

# %%
vlans_list

# %%
vlans = []

# %%
for item in vlans_list:
    if 'vlan' in item:
        temp = {}
        id = item.strip().strip('vlan').strip()
        temp['id'] = id
    elif 'name' in item:
        name = item.strip().strip('name').strip()
        temp['name'] = name
        vlans.append(temp)

# %%
vlans

# %%
vlans_file.close()

# %%
# '    name WLAN' => WLAN
#'    name WLAN'.strip().strip('name').strip()

# %% [markdown]
# ## Writing to a File

# %%
vlans

# %%
add_vlan = {'id': '70', 'name': 'MISC'}
vlans.append(add_vlan)

add_vlan = {'id': '80', 'name': 'HQ'}
vlans.append(add_vlan)

# %%
vlans

# %%
write_file = open('vlans_new.cfg', 'w')

for vlan in vlans:
    id = vlan.get('id')
    name = vlan.get('name')
    write_file.write('vlan ' + id + '\n')
    write_file.write(' name ' + name + '\n')

# %%
write_file.close()
